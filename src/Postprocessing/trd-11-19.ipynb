# %%
import matplotlib
import pandas

df = pandas.read_csv("../../export.csv")
# Out:
# /home/matt/Documents/pyqt_groundstation/.venv/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3139: DtypeWarning: Columns (52) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
import matplotlib.pyplot as plt

good_crc = df[(df["crc"] == "Good")]
# good_crc = df # df[(df['crc'] == "Good")]

plt.figure()
# plt.plot(good_crc["time_stamp_ms"] / 1000, good_crc["fcb_state_number"])
plt.subplot(311)
plt.plot(good_crc["fcb_state_number"])
plt.xlim((50000))
plt.ylim(0, 8)
plt.subplot(312)
plt.plot(good_crc["accel_x"])
plt.plot(good_crc["accel_y"])
plt.plot(good_crc["accel_z"])
plt.xlim((50000))
plt.ylim(-20, 20)
plt.subplot(313)
plt.plot(good_crc["fcb_altitude"])
plt.xlim((54000))
plt.show()
